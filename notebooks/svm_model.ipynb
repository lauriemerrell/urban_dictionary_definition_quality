# %%
# Following: https://scikit-learn.org/stable/tutorial/text_analytics/working_with_text_data.html
# Adapted from homework 3 for Text Analytics course

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib
import datetime

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.svm import LinearSVC
from sklearn.metrics import f1_score

# %% [markdown]
# ## Load and split data

# %%
# load data
data = pd.read_csv('../data/clean_data.csv')

# %%
data.columns
# Out:
# Index(['word_id', 'word', 'up_votes', 'down_votes', 'author', 'definition',
#        'total_votes', 'good_ratio', 'cat', 'char_len', 'word_len',
#        'word_len_bucket'],
#       dtype='object')

# %%
# split into train/test - need to use tokenizer trained on train only
defn = data[['definition','cat']]
train = defn.sample(frac = .8, random_state = 771)
test = defn[~defn.index.isin(train.index)]
X_train = train['definition']
y_train = train['cat']
X_test = test['definition']
y_test = test['cat']

# %% [markdown]
# ## Examine raw counts
# Get a sense of word frequencies

# %%
# first examine the raw counts
# count_vect = CountVectorizer()
# X_train_counts = count_vect.fit_transform(X_train)

# %%
# follow: https://medium.com/@cristhianboujon/how-to-list-the-most-common-words-from-text-corpus-using-scikit-learn-dad4d0cab41d
# to get most common words
# sum_words = X_train_counts.sum(axis=0)
# words_freq = [(word, sum_words[0, idx]) for word, idx in count_vect.vocabulary_.items()]

# %%
# X_train_counts.shape[1]

# %%
# len(train)

# %%
# freq = pd.DataFrame(words_freq, columns = ["word","freq"])

# %%
# freq.sort_values(by = "freq", ascending = False).head(50)

# %% [markdown]
# ## SVM comparison loop

# %%
# test combinations of: min_df, max_df, lower for tokenizer
results = []
for max_df in [.1, .05, .025, .01]:
    for min_df in [3, 5]:
        for lower in [True, False]:
            for dual in [True, False]:
                print("Working on: max_df = " + str(max_df) + " min_df = " + str(min_df) + " lower = " + str(lower) + " dual = " + str(dual))
                # raw counts
                # to print time: https://www.geeksforgeeks.org/get-current-date-and-time-using-python/
                print("Count vectorizing at " + str(datetime.datetime.now()))
                cv = CountVectorizer(max_df = max_df, min_df = min_df, lowercase = lower)
                X_train_counts = cv.fit_transform(X_train)
                X_test_counts = cv.transform(X_test)
                
                # record vocab size for tracking
                vocab_size = X_train_counts.shape[1]
                
                # tf-idf version
                print("TF-IDF vectorizing at " + str(datetime.datetime.now()))
                tv = TfidfTransformer()
                X_train_tfidf = tv.fit_transform(X_train_counts)
                X_test_tfidf = tv.transform(X_test_counts)
                
                # fit an SVM on tf-idf version
                print("Fitting TF-IDF count SVM at " + str(datetime.datetime.now()))
                svm_tf = LinearSVC(dual = dual, random_state = 771, max_iter = 5000)
                svm_tf.fit(X_train_tfidf, y_train)
                
                # evaluate 
                print("Evaluating TF-IDF SVM at " + str(datetime.datetime.now()))
                tf_y_train_pred = svm_tf.predict(X_train_tfidf)
                tf_y_test_pred = svm_tf.predict(X_test_tfidf)
                
                tf_train_f1_micro = f1_score(y_train, tf_y_train_pred, average = 'micro')
                tf_train_f1_macro = f1_score(y_train, tf_y_train_pred, average = 'macro')
                
                tf_test_f1_micro = f1_score(y_test, tf_y_test_pred, average = 'micro')
                tf_test_f1_macro = f1_score(y_test, tf_y_test_pred, average = 'macro')
                
                # record
                curr_tfidf_results = ("tfidf", max_df, min_df, lower, dual, vocab_size, tf_train_f1_micro, 
                                tf_train_f1_macro, tf_test_f1_micro, tf_test_f1_macro)
                print(curr_tfidf_results)
                results.append(curr_tfidf_results)
                print("--------------------------------------------------------")
                
                
full_results = pd.DataFrame(results, columns = ["type", "max_df", "min_df", "lower", "dual", "vocab_size",
                                               "train_micro_f1", "train_macro_f1", "test_micro_f1", "test_macro_f1"])
full_results.to_csv("../models/svm_results.csv", index = False)
# Out:
# Working on: max_df = 0.1 min_df = 3 lower = True dual = True
# Count vectorizing at 2020-11-20 20:49:57.796538
# TF-IDF vectorizing at 2020-11-20 20:50:16.362684
# Fitting TF-IDF count SVM at 2020-11-20 20:50:17.240393
# Evaluating TF-IDF SVM at 2020-11-20 20:51:01.483598
# ('tfidf', 0.1, 3, True, True, 89202, 0.5303295981090081, 0.5300672188390038, 0.39561161767061176, 0.39517904621245187)
# --------------------------------------------------------
# Working on: max_df = 0.1 min_df = 3 lower = True dual = False
# Count vectorizing at 2020-11-20 20:51:12.356171
# TF-IDF vectorizing at 2020-11-20 20:51:29.324423
# Fitting TF-IDF count SVM at 2020-11-20 20:51:30.224547
# Evaluating TF-IDF SVM at 2020-11-20 20:53:17.414606
# ('tfidf', 0.1, 3, True, False, 89202, 0.5302964615698987, 0.5300339871642753, 0.3956337086966847, 0.3952014867151332)
# --------------------------------------------------------
# Working on: max_df = 0.1 min_df = 3 lower = False dual = True
# Count vectorizing at 2020-11-20 20:53:28.668812
# TF-IDF vectorizing at 2020-11-20 20:53:46.017993
# Fitting TF-IDF count SVM at 2020-11-20 20:53:46.968478
# Evaluating TF-IDF SVM at 2020-11-20 20:54:30.674088
# ('tfidf', 0.1, 3, False, True, 113146, 0.5526898585622055, 0.5525461516920774, 0.39492679586235085, 0.3946051995371082)
# --------------------------------------------------------
# Working on: max_df = 0.1 min_df = 3 lower = False dual = False
# Count vectorizing at 2020-11-20 20:54:41.479420
# TF-IDF vectorizing at 2020-11-20 20:54:58.984945
# Fitting TF-IDF count SVM at 2020-11-20 20:54:59.907460
# Evaluating TF-IDF SVM at 2020-11-20 20:56:45.503395
# ('tfidf', 0.1, 3, False, False, 113146, 0.5526139206600799, 0.5524707062973259, 0.3949875461840514, 0.39466779332137186)
# --------------------------------------------------------
# Working on: max_df = 0.1 min_df = 5 lower = True dual = True
# Count vectorizing at 2020-11-20 20:56:56.818650
# TF-IDF vectorizing at 2020-11-20 20:57:13.818261
# Fitting TF-IDF count SVM at 2020-11-20 20:57:14.677287
# Evaluating TF-IDF SVM at 2020-11-20 20:57:57.681128
# ('tfidf', 0.1, 5, True, True, 62963, 0.5093265550701667, 0.5089512724916766, 0.39678244205247726, 0.3961903155916937)
# --------------------------------------------------------
# Working on: max_df = 0.1 min_df = 5 lower = True dual = False
# Count vectorizing at 2020-11-20 20:58:08.471005
# TF-IDF vectorizing at 2020-11-20 20:58:25.238975
# Fitting TF-IDF count SVM at 2020-11-20 20:58:26.121710
# Evaluating TF-IDF SVM at 2020-11-20 20:59:49.316296
# ('tfidf', 0.1, 5, True, False, 62963, 0.509203673737636, 0.5088260517297293, 0.39674930551336784, 0.39615566962221255)
# --------------------------------------------------------
# Working on: max_df = 0.1 min_df = 5 lower = False dual = True
# Count vectorizing at 2020-11-20 21:00:00.460637
# TF-IDF vectorizing at 2020-11-20 21:00:17.798435
# Fitting TF-IDF count SVM at 2020-11-20 21:00:18.718423
# Evaluating TF-IDF SVM at 2020-11-20 21:01:02.464997
# ('tfidf', 0.1, 5, False, True, 79004, 0.5274370543825835, 0.5272079848319723, 0.394976500671015, 0.3945613471691222)
# --------------------------------------------------------
# Working on: max_df = 0.1 min_df = 5 lower = False dual = False
# Count vectorizing at 2020-11-20 21:04:14.922591
# TF-IDF vectorizing at 2020-11-20 21:04:35.183012
# Fitting TF-IDF count SVM at 2020-11-20 21:04:36.388206
# Evaluating TF-IDF SVM at 2020-11-20 21:06:18.908270
# ('tfidf', 0.1, 5, False, False, 79004, 0.5274149633565105, 0.5271847876998188, 0.39489918207975966, 0.39448253921910076)
# --------------------------------------------------------
# Working on: max_df = 0.05 min_df = 3 lower = True dual = True
# Count vectorizing at 2020-11-20 21:06:30.709042
# TF-IDF vectorizing at 2020-11-20 21:06:48.628788
# Fitting TF-IDF count SVM at 2020-11-20 21:06:49.413342
# Evaluating TF-IDF SVM at 2020-11-20 21:07:31.607549
# ('tfidf', 0.05, 3, True, True, 89176, 0.5302522795177529, 0.5300026816199684, 0.39515875163611663, 0.394754934369083)
# --------------------------------------------------------
# Working on: max_df = 0.05 min_df = 3 lower = True dual = False
# Count vectorizing at 2020-11-20 21:07:42.447240
# TF-IDF vectorizing at 2020-11-20 21:07:59.449090
# Fitting TF-IDF count SVM at 2020-11-20 21:08:00.229051
# Evaluating TF-IDF SVM at 2020-11-20 21:09:25.692943
# ('tfidf', 0.05, 3, True, False, 89176, 0.5302219043569026, 0.5299717656302482, 0.39516979714915307, 0.3947608163796337)
# --------------------------------------------------------
# Working on: max_df = 0.05 min_df = 3 lower = False dual = True
# Count vectorizing at 2020-11-20 21:09:36.923091
# TF-IDF vectorizing at 2020-11-20 21:09:54.268702
# Fitting TF-IDF count SVM at 2020-11-20 21:09:55.117796
# Evaluating TF-IDF SVM at 2020-11-20 21:10:37.156844
# ('tfidf', 0.05, 3, False, True, 113122, 0.5528776322838255, 0.5527464482902482, 0.39448497534089216, 0.394180751580989)
# --------------------------------------------------------
# Working on: max_df = 0.05 min_df = 3 lower = False dual = False
# Count vectorizing at 2020-11-20 21:10:47.915413
# TF-IDF vectorizing at 2020-11-20 21:11:05.149241
# Fitting TF-IDF count SVM at 2020-11-20 21:11:05.974933
# Evaluating TF-IDF SVM at 2020-11-20 21:12:33.088209
# ('tfidf', 0.05, 3, False, False, 113122, 0.5528513991903639, 0.5527197116788255, 0.3944904980974104, 0.3941879980462182)
# --------------------------------------------------------
# Working on: max_df = 0.05 min_df = 5 lower = True dual = True
# Count vectorizing at 2020-11-20 21:12:44.622824
# TF-IDF vectorizing at 2020-11-20 21:13:01.564925
# Fitting TF-IDF count SVM at 2020-11-20 21:13:02.349421
# Evaluating TF-IDF SVM at 2020-11-20 21:13:43.657561
# ('tfidf', 0.05, 5, True, True, 62937, 0.5091125482550851, 0.5087525758147108, 0.395948505818224, 0.3953740941688264)
# --------------------------------------------------------
# Working on: max_df = 0.05 min_df = 5 lower = True dual = False
# Count vectorizing at 2020-11-20 21:13:54.541733
# TF-IDF vectorizing at 2020-11-20 21:14:11.347701
# Fitting TF-IDF count SVM at 2020-11-20 21:14:12.136694
# Evaluating TF-IDF SVM at 2020-11-20 21:15:25.171205
# ('tfidf', 0.05, 5, True, False, 62937, 0.5090945992964008, 0.508735154318037, 0.3960037333834063, 0.39543342319594244)
# --------------------------------------------------------
# Working on: max_df = 0.05 min_df = 5 lower = False dual = True
# Count vectorizing at 2020-11-20 21:15:36.280052
# TF-IDF vectorizing at 2020-11-20 21:15:53.620950
# Fitting TF-IDF count SVM at 2020-11-20 21:15:54.463625
# Evaluating TF-IDF SVM at 2020-11-20 21:16:36.140552
# ('tfidf', 0.05, 5, False, True, 78980, 0.5274536226521381, 0.5272438898668176, 0.3952526384969266, 0.39486200802984367)
# --------------------------------------------------------
# Working on: max_df = 0.05 min_df = 5 lower = False dual = False
# Count vectorizing at 2020-11-20 21:16:46.922698
# TF-IDF vectorizing at 2020-11-20 21:17:04.164332
# Fitting TF-IDF count SVM at 2020-11-20 21:17:05.009649
# Evaluating TF-IDF SVM at 2020-11-20 21:18:30.034265
# ('tfidf', 0.05, 5, False, False, 78980, 0.5274812364347293, 0.5272720342318907, 0.3952526384969266, 0.3948631523986235)
# --------------------------------------------------------
# Working on: max_df = 0.025 min_df = 3 lower = True dual = True
# Count vectorizing at 2020-11-20 21:18:41.543562
# TF-IDF vectorizing at 2020-11-20 21:18:58.643348
# Fitting TF-IDF count SVM at 2020-11-20 21:18:59.323914
# Evaluating TF-IDF SVM at 2020-11-20 21:19:38.722273
# ('tfidf', 0.025, 3, True, True, 89120, 0.5297359017832981, 0.5295013634902634, 0.39427511059319925, 0.39388887375066)
# --------------------------------------------------------
# Working on: max_df = 0.025 min_df = 3 lower = True dual = False
# Count vectorizing at 2020-11-20 21:19:49.467769
# TF-IDF vectorizing at 2020-11-20 21:20:06.560398
# Fitting TF-IDF count SVM at 2020-11-20 21:20:07.245340
# Evaluating TF-IDF SVM at 2020-11-20 21:21:13.223967
# ('tfidf', 0.025, 3, True, False, 89120, 0.5297069073115773, 0.52947111949414, 0.39439661123660036, 0.3940108583029602)
# --------------------------------------------------------
# Working on: max_df = 0.025 min_df = 3 lower = False dual = True
# Count vectorizing at 2020-11-20 21:21:24.669329
# TF-IDF vectorizing at 2020-11-20 21:21:42.403729
# Fitting TF-IDF count SVM at 2020-11-20 21:21:43.163767
# Evaluating TF-IDF SVM at 2020-11-20 21:30:36.587417
# ('tfidf', 0.025, 3, False, True, 113063, 0.552522795177529, 0.5523998047247449, 0.393938222445587, 0.39363843987049024)
# --------------------------------------------------------
# Working on: max_df = 0.025 min_df = 3 lower = False dual = False
# Count vectorizing at 2020-11-20 21:30:47.625920
# TF-IDF vectorizing at 2020-11-20 21:31:05.082967
# Fitting TF-IDF count SVM at 2020-11-20 21:31:05.832623
# Evaluating TF-IDF SVM at 2020-11-20 21:32:17.237671
# ('tfidf', 0.025, 3, False, False, 113063, 0.5525214144883994, 0.5523994603646217, 0.3939161314195141, 0.3936170129318292)
# --------------------------------------------------------
# Working on: max_df = 0.025 min_df = 5 lower = True dual = True
# Count vectorizing at 2020-11-20 21:32:28.727224
# TF-IDF vectorizing at 2020-11-20 21:32:45.673848
# Fitting TF-IDF count SVM at 2020-11-20 21:32:46.377317
# Evaluating TF-IDF SVM at 2020-11-20 21:33:25.856149
# ('tfidf', 0.025, 5, True, True, 62881, 0.5086914380705698, 0.5083425597251457, 0.3952360702273719, 0.3946910293877924)
# --------------------------------------------------------
# Working on: max_df = 0.025 min_df = 5 lower = True dual = False
# Count vectorizing at 2020-11-20 21:33:36.644034
# TF-IDF vectorizing at 2020-11-20 21:33:53.360949
# Fitting TF-IDF count SVM at 2020-11-20 21:33:54.053061
# Evaluating TF-IDF SVM at 2020-11-20 21:34:48.872174
# ('tfidf', 0.025, 5, True, False, 62881, 0.5087093870292541, 0.5083577652069201, 0.3952471157404083, 0.394703664960776)
# --------------------------------------------------------
# Working on: max_df = 0.025 min_df = 5 lower = False dual = True
# Count vectorizing at 2020-11-20 21:35:00.236551
# TF-IDF vectorizing at 2020-11-20 21:35:17.526726
# Fitting TF-IDF count SVM at 2020-11-20 21:35:18.249985
# Evaluating TF-IDF SVM at 2020-11-20 21:35:58.140969
# ('tfidf', 0.025, 5, False, True, 78921, 0.5267522325743225, 0.5265388828602845, 0.3943413836714181, 0.39398449615235426)
# --------------------------------------------------------
# Working on: max_df = 0.025 min_df = 5 lower = False dual = False
# Count vectorizing at 2020-11-20 21:36:09.059114
# TF-IDF vectorizing at 2020-11-20 21:36:26.349435
# Fitting TF-IDF count SVM at 2020-11-20 21:36:27.077935
# Evaluating TF-IDF SVM at 2020-11-20 21:37:27.056198
# ('tfidf', 0.025, 5, False, False, 78921, 0.5267121925895653, 0.5265008509475897, 0.39430272437579045, 0.39394775592198417)
# --------------------------------------------------------
# Working on: max_df = 0.01 min_df = 3 lower = True dual = True
# Count vectorizing at 2020-11-20 21:37:38.704107
# TF-IDF vectorizing at 2020-11-20 21:37:55.639379
# Fitting TF-IDF count SVM at 2020-11-20 21:37:56.193717
# Evaluating TF-IDF SVM at 2020-11-20 21:38:33.291475
# ('tfidf', 0.01, 3, True, True, 88958, 0.5286603449513722, 0.5283832811172569, 0.3913314813689809, 0.3909064887946156)
# --------------------------------------------------------
# Working on: max_df = 0.01 min_df = 3 lower = True dual = False
# Count vectorizing at 2020-11-20 21:38:44.030649
# TF-IDF vectorizing at 2020-11-20 21:39:00.783671
# Fitting TF-IDF count SVM at 2020-11-20 21:39:01.366680
# Evaluating TF-IDF SVM at 2020-11-20 21:39:45.868803
# ('tfidf', 0.01, 3, True, False, 88958, 0.528645157370947, 0.5283676736613055, 0.39128729931683504, 0.3908595385964088)
# --------------------------------------------------------
# Working on: max_df = 0.01 min_df = 3 lower = False dual = True
# Count vectorizing at 2020-11-20 21:39:57.009700
# TF-IDF vectorizing at 2020-11-20 21:40:14.399885
# Fitting TF-IDF count SVM at 2020-11-20 21:40:15.018085
# Evaluating TF-IDF SVM at 2020-11-20 21:40:52.623335
# ('tfidf', 0.01, 3, False, True, 112898, 0.552000894686556, 0.5518726566625467, 0.3909835477083322, 0.39071718471005407)
# --------------------------------------------------------
# Working on: max_df = 0.01 min_df = 3 lower = False dual = False
# Count vectorizing at 2020-11-20 21:41:03.457256
# TF-IDF vectorizing at 2020-11-20 21:41:20.980796
# Fitting TF-IDF count SVM at 2020-11-20 21:41:21.616310
# Evaluating TF-IDF SVM at 2020-11-20 21:42:13.160523
# ('tfidf', 0.01, 3, False, False, 112898, 0.55195671263441, 0.5518312987377068, 0.3909393656561863, 0.39067614528952727)
# --------------------------------------------------------
# Working on: max_df = 0.01 min_df = 5 lower = True dual = True
# Count vectorizing at 2020-11-20 21:42:24.873000
# TF-IDF vectorizing at 2020-11-20 21:42:41.925968
# Fitting TF-IDF count SVM at 2020-11-20 21:42:42.485042
# Evaluating TF-IDF SVM at 2020-11-20 21:43:19.266679
# ('tfidf', 0.01, 5, True, True, 62719, 0.5072817544692907, 0.5069034404949341, 0.392540965046474, 0.39196485316486845)
# --------------------------------------------------------
# Working on: max_df = 0.01 min_df = 5 lower = True dual = False
# Count vectorizing at 2020-11-20 21:43:30.056927
# TF-IDF vectorizing at 2020-11-20 21:43:46.900114
# Fitting TF-IDF count SVM at 2020-11-20 21:43:47.506555
# Evaluating TF-IDF SVM at 2020-11-20 22:06:55.781497
# ('tfidf', 0.01, 5, True, False, 62719, 0.5072776124019021, 0.5068997809504989, 0.392540965046474, 0.39196491001171924)
# --------------------------------------------------------
# Working on: max_df = 0.01 min_df = 5 lower = False dual = True
# Count vectorizing at 2020-11-20 22:07:06.944304
# TF-IDF vectorizing at 2020-11-20 22:07:25.468511
# Fitting TF-IDF count SVM at 2020-11-20 22:07:26.074468
# Evaluating TF-IDF SVM at 2020-11-20 22:08:03.200050
# ('tfidf', 0.01, 5, False, True, 78756, 0.525912773583551, 0.5256889475221899, 0.39183957496865834, 0.39149019336436713)
# --------------------------------------------------------
# Working on: max_df = 0.01 min_df = 5 lower = False dual = False
# Count vectorizing at 2020-11-20 22:08:13.943895
# TF-IDF vectorizing at 2020-11-20 22:08:31.221772
# Fitting TF-IDF count SVM at 2020-11-20 22:08:31.817661
# Evaluating TF-IDF SVM at 2020-11-20 22:09:15.274223
# ('tfidf', 0.01, 5, False, False, 78756, 0.52585340395098, 0.5256291486972753, 0.39183957496865834, 0.39148994556466027)
# --------------------------------------------------------

# %%
full_results.head()
# Out:
#     type  max_df  min_df  lower   dual  vocab_size  train_micro_f1  \
# 0  tfidf     0.1       3   True   True       89202        0.530330
# 1  tfidf     0.1       3   True  False       89202        0.530296
# 2  tfidf     0.1       3  False   True      113146        0.552690
# 3  tfidf     0.1       3  False  False      113146        0.552614
# 4  tfidf     0.1       5   True   True       62963        0.509327
#
#    train_macro_f1  test_micro_f1  test_macro_f1
# 0        0.530067       0.395612       0.395179
# 1        0.530034       0.395634       0.395201
# 2        0.552546       0.394927       0.394605
# 3        0.552471       0.394988       0.394668
# 4        0.508951       0.396782       0.396190

# %%
full_results.sort_values(by = "test_micro_f1", ascending = False)
# Out:
#      type  max_df  min_df  lower   dual  vocab_size  train_micro_f1  \
# 4   tfidf   0.100       5   True   True       62963        0.509327
# 5   tfidf   0.100       5   True  False       62963        0.509204
# 13  tfidf   0.050       5   True  False       62937        0.509095
# 12  tfidf   0.050       5   True   True       62937        0.509113
# 1   tfidf   0.100       3   True  False       89202        0.530296
# 0   tfidf   0.100       3   True   True       89202        0.530330
# 15  tfidf   0.050       5  False  False       78980        0.527481
# 14  tfidf   0.050       5  False   True       78980        0.527454
# 21  tfidf   0.025       5   True  False       62881        0.508709
# 20  tfidf   0.025       5   True   True       62881        0.508691
# 9   tfidf   0.050       3   True  False       89176        0.530222
# 8   tfidf   0.050       3   True   True       89176        0.530252
# 3   tfidf   0.100       3  False  False      113146        0.552614
# 6   tfidf   0.100       5  False   True       79004        0.527437
# 2   tfidf   0.100       3  False   True      113146        0.552690
# 7   tfidf   0.100       5  False  False       79004        0.527415
# 11  tfidf   0.050       3  False  False      113122        0.552851
# 10  tfidf   0.050       3  False   True      113122        0.552878
# 17  tfidf   0.025       3   True  False       89120        0.529707
# 22  tfidf   0.025       5  False   True       78921        0.526752
# 23  tfidf   0.025       5  False  False       78921        0.526712
# 16  tfidf   0.025       3   True   True       89120        0.529736
# 18  tfidf   0.025       3  False   True      113063        0.552523
# 19  tfidf   0.025       3  False  False      113063        0.552521
# 28  tfidf   0.010       5   True   True       62719        0.507282
# 29  tfidf   0.010       5   True  False       62719        0.507278
# 30  tfidf   0.010       5  False   True       78756        0.525913
# 31  tfidf   0.010       5  False  False       78756        0.525853
# 24  tfidf   0.010       3   True   True       88958        0.528660
# 25  tfidf   0.010       3   True  False       88958        0.528645
# 26  tfidf   0.010       3  False   True      112898        0.552001
# 27  tfidf   0.010       3  False  False      112898        0.551957
#
#     train_macro_f1  test_micro_f1  test_macro_f1
# 4         0.508951       0.396782       0.396190
# 5         0.508826       0.396749       0.396156
# 13        0.508735       0.396004       0.395433
# 12        0.508753       0.395949       0.395374
# 1         0.530034       0.395634       0.395201
# 0         0.530067       0.395612       0.395179
# 15        0.527272       0.395253       0.394863
# 14        0.527244       0.395253       0.394862
# 21        0.508358       0.395247       0.394704
# 20        0.508343       0.395236       0.394691
# 9         0.529972       0.395170       0.394761
# 8         0.530003       0.395159       0.394755
# 3         0.552471       0.394988       0.394668
# 6         0.527208       0.394977       0.394561
# 2         0.552546       0.394927       0.394605
# 7         0.527185       0.394899       0.394483
# 11        0.552720       0.394490       0.394188
# 10        0.552746       0.394485       0.394181
# 17        0.529471       0.394397       0.394011
# 22        0.526539       0.394341       0.393984
# 23        0.526501       0.394303       0.393948
# 16        0.529501       0.394275       0.393889
# 18        0.552400       0.393938       0.393638
# 19        0.552399       0.393916       0.393617
# 28        0.506903       0.392541       0.391965
# 29        0.506900       0.392541       0.391965
# 30        0.525689       0.391840       0.391490
# 31        0.525629       0.391840       0.391490
# 24        0.528383       0.391331       0.390906
# 25        0.528368       0.391287       0.390860
# 26        0.551873       0.390984       0.390717
# 27        0.551831       0.390939       0.390676

# %%
# add cases where we don't drop any of the most common words

# test combinations of: min_df, max_df, lower for tokenizer
results2 = []
for max_df in [1.0]:
    for min_df in [1, 3, 5]:
        for lower in [True, False]:
            for dual in [True, False]:
                print("Working on: max_df = " + str(max_df) + " min_df = " + str(min_df) + " lower = " + str(lower) + " dual = " + str(dual))
                # raw counts
                # to print time: https://www.geeksforgeeks.org/get-current-date-and-time-using-python/
                print("Count vectorizing at " + str(datetime.datetime.now()))
                cv = CountVectorizer(max_df = max_df, min_df = min_df, lowercase = lower)
                X_train_counts = cv.fit_transform(X_train)
                X_test_counts = cv.transform(X_test)
                # record vocab size for tracking
                vocab_size = X_train_counts.shape[1]
                # tf-idf version
                print("TF-IDF vectorizing at " + str(datetime.datetime.now()))
                tv = TfidfTransformer()
                X_train_tfidf = tv.fit_transform(X_train_counts)
                X_test_tfidf = tv.transform(X_test_counts)
                
                # fit an SVM on tf-idf version
                print("Fitting TF-IDF count SVM at " + str(datetime.datetime.now()))
                svm_tf = LinearSVC(dual = dual, random_state = 771, max_iter = 5000)
                svm_tf.fit(X_train_tfidf, y_train)
                
                # evaluate 
                print("Evaluating TF-IDF SVM at " + str(datetime.datetime.now()))
                tf_y_train_pred = svm_tf.predict(X_train_tfidf)
                tf_y_test_pred = svm_tf.predict(X_test_tfidf)
                
                tf_train_f1_micro = f1_score(y_train, tf_y_train_pred, average = 'micro')
                tf_train_f1_macro = f1_score(y_train, tf_y_train_pred, average = 'macro')
                
                tf_test_f1_micro = f1_score(y_test, tf_y_test_pred, average = 'micro')
                tf_test_f1_macro = f1_score(y_test, tf_y_test_pred, average = 'macro')
                
                # record
                curr_tfidf_results = ("tfidf", max_df, min_df, lower, dual, vocab_size, tf_train_f1_micro, 
                                tf_train_f1_macro, tf_test_f1_micro, tf_test_f1_macro)
                print(curr_tfidf_results)
                results2.append(curr_tfidf_results)
                print("--------------------------------------------------------")
                
full_results2 = full_results.append(pd.DataFrame(results2, columns = ["type", "max_df", "min_df", "lower", "dual", "vocab_size",
                                               "train_micro_f1", "train_macro_f1", "test_micro_f1", "test_macro_f1"]))
full_results2.to_csv("../models/svm_results_with_all_common.csv", index = False)
# Out:
# Working on: max_df = 1.0 min_df = 1 lower = True dual = True
# Count vectorizing at 2020-11-20 22:24:29.936490
# TF-IDF vectorizing at 2020-11-20 22:24:48.836587
# Fitting TF-IDF count SVM at 2020-11-20 22:24:50.413288
# Evaluating TF-IDF SVM at 2020-11-20 22:25:44.319926
# ('tfidf', 1.0, 1, True, True, 314448, 0.6183402459835753, 0.6183218188913892, 0.39657257730478435, 0.3963829330648622)
# --------------------------------------------------------
# Working on: max_df = 1.0 min_df = 1 lower = True dual = False
# Count vectorizing at 2020-11-20 22:25:55.162515
# TF-IDF vectorizing at 2020-11-20 22:26:12.331852
# Fitting TF-IDF count SVM at 2020-11-20 22:26:13.783596
# Evaluating TF-IDF SVM at 2020-11-20 22:29:24.483202
# ('tfidf', 1.0, 1, True, False, 314448, 0.61826292739232, 0.618244227019647, 0.396517349739602, 0.39632601256600736)
# --------------------------------------------------------
# Working on: max_df = 1.0 min_df = 1 lower = False dual = True
# Count vectorizing at 2020-11-20 22:29:35.474998
# TF-IDF vectorizing at 2020-11-20 22:29:53.753627
# Fitting TF-IDF count SVM at 2020-11-20 22:29:55.454311
# Evaluating TF-IDF SVM at 2020-11-20 22:30:46.846734
# ('tfidf', 1.0, 1, False, True, 403015, 0.6533973236721913, 0.6534273609420306, 0.3954183211924736, 0.3953482129620978)
# --------------------------------------------------------
# Working on: max_df = 1.0 min_df = 1 lower = False dual = False
# Count vectorizing at 2020-11-20 22:30:57.692321
# TF-IDF vectorizing at 2020-11-20 22:31:15.545802
# Fitting TF-IDF count SVM at 2020-11-20 22:31:17.143151
# Evaluating TF-IDF SVM at 2020-11-20 22:34:18.290276
# ('tfidf', 1.0, 1, False, False, 403015, 0.6532910106092152, 0.6533210204280676, 0.39534100260121824, 0.395271612976073)
# --------------------------------------------------------
# Working on: max_df = 1.0 min_df = 3 lower = True dual = True
# Count vectorizing at 2020-11-20 22:34:29.367330
# TF-IDF vectorizing at 2020-11-20 22:34:46.340665
# Fitting TF-IDF count SVM at 2020-11-20 22:34:47.474709
# Evaluating TF-IDF SVM at 2020-11-20 22:35:46.071504
# ('tfidf', 1.0, 3, True, True, 89225, 0.5298408341571446, 0.5295622558962251, 0.3965283952526385, 0.39608057485147735)
# --------------------------------------------------------
# Working on: max_df = 1.0 min_df = 3 lower = True dual = False
# Count vectorizing at 2020-11-20 23:13:31.828546
# TF-IDF vectorizing at 2020-11-21 00:06:19.480327
# Fitting TF-IDF count SVM at 2020-11-21 00:06:34.356845
# Evaluating TF-IDF SVM at 2020-11-21 07:19:04.894855
# ('tfidf', 1.0, 3, True, False, 89225, 0.5298228851984602, 0.5295443293141516, 0.3965615317917479, 0.39611538661374057)
# --------------------------------------------------------
# Working on: max_df = 1.0 min_df = 3 lower = False dual = True
# Count vectorizing at 2020-11-21 08:00:03.438075
# TF-IDF vectorizing at 2020-11-21 08:01:13.406671
# Fitting TF-IDF count SVM at 2020-11-21 08:01:15.890347
# Evaluating TF-IDF SVM at 2020-11-21 08:02:10.391555
# ('tfidf', 1.0, 3, False, True, 113168, 0.552450999342792, 0.5522925051267706, 0.39544041221854653, 0.3950916778430114)
# --------------------------------------------------------
# Working on: max_df = 1.0 min_df = 3 lower = False dual = False
# Count vectorizing at 2020-11-21 08:02:22.535995
# TF-IDF vectorizing at 2020-11-21 08:02:41.962466
# Fitting TF-IDF count SVM at 2020-11-21 08:02:43.244623
# Evaluating TF-IDF SVM at 2020-11-21 08:05:57.259065
# ('tfidf', 1.0, 3, False, False, 113168, 0.5524482379645329, 0.5522901890150618, 0.39545145773158297, 0.39510379686531366)
# --------------------------------------------------------
# Working on: max_df = 1.0 min_df = 5 lower = True dual = True
# Count vectorizing at 2020-11-21 08:06:13.392304
# TF-IDF vectorizing at 2020-11-21 08:06:32.949345
# Fitting TF-IDF count SVM at 2020-11-21 08:06:34.211107
# Evaluating TF-IDF SVM at 2020-11-21 08:07:25.562366
# ('tfidf', 1.0, 5, True, True, 62986, 0.5092381909658749, 0.5088505856254814, 0.397014397826243, 0.3964110655263852)
# --------------------------------------------------------
# Working on: max_df = 1.0 min_df = 5 lower = True dual = False
# Count vectorizing at 2020-11-21 08:07:38.185335
# TF-IDF vectorizing at 2020-11-21 08:07:57.406155
# Fitting TF-IDF count SVM at 2020-11-21 08:07:58.751633
# Evaluating TF-IDF SVM at 2020-11-21 08:10:55.858834
# ('tfidf', 1.0, 5, True, False, 62986, 0.5091926282245994, 0.5088039358064597, 0.3970420116088342, 0.39643893399687774)
# --------------------------------------------------------
# Working on: max_df = 1.0 min_df = 5 lower = False dual = True
# Count vectorizing at 2020-11-21 08:11:13.286181
# TF-IDF vectorizing at 2020-11-21 08:11:33.226448
# Fitting TF-IDF count SVM at 2020-11-21 08:11:34.564643
# Evaluating TF-IDF SVM at 2020-11-21 08:12:28.167305
# ('tfidf', 1.0, 5, False, True, 79026, 0.5275557936477254, 0.5272914663987148, 0.395782823122677, 0.39537026413659077)
# --------------------------------------------------------
# Working on: max_df = 1.0 min_df = 5 lower = False dual = False
# Count vectorizing at 2020-11-21 08:12:40.862330
# TF-IDF vectorizing at 2020-11-21 08:13:02.047868
# Fitting TF-IDF count SVM at 2020-11-21 08:13:03.389080
# Evaluating TF-IDF SVM at 2020-11-21 08:15:51.699545
# ('tfidf', 1.0, 5, False, False, 79026, 0.527522657108616, 0.527257655485939, 0.3957938686357135, 0.39538488726495596)
# --------------------------------------------------------

# %%
full_results2['test_macro_f1'].describe()
# Out:
# count    44.000000
# mean      0.394349
# std       0.001668
# min       0.390676
# 25%       0.393933
# 50%       0.394729
# 75%       0.395371
# max       0.396439
# Name: test_macro_f1, dtype: float64

# %%
full_results2['test_micro_f1'].describe()
# Out:
# count    44.000000
# mean      0.394744
# std       0.001689
# min       0.390939
# 25%       0.394296
# 50%       0.395203
# 75%       0.395786
# max       0.397042
# Name: test_micro_f1, dtype: float64

# %%
full_results2.sort_values(by = 'of', ascending = False)
# Out:
#      type  max_df  min_df  lower   dual  vocab_size  train_micro_f1  \
# 2   tfidf   1.000       1  False   True      403015        0.653397
# 3   tfidf   1.000       1  False  False      403015        0.653291
# 0   tfidf   1.000       1   True   True      314448        0.618340
# 1   tfidf   1.000       1   True  False      314448        0.618263
# 26  tfidf   0.010       3  False   True      112898        0.552001
# 27  tfidf   0.010       3  False  False      112898        0.551957
# 19  tfidf   0.025       3  False  False      113063        0.552521
# 18  tfidf   0.025       3  False   True      113063        0.552523
# 10  tfidf   0.050       3  False   True      113122        0.552878
# 11  tfidf   0.050       3  False  False      113122        0.552851
# 2   tfidf   0.100       3  False   True      113146        0.552690
# 3   tfidf   0.100       3  False  False      113146        0.552614
# 6   tfidf   1.000       3  False   True      113168        0.552451
# 7   tfidf   1.000       3  False  False      113168        0.552448
# 25  tfidf   0.010       3   True  False       88958        0.528645
# 24  tfidf   0.010       3   True   True       88958        0.528660
# 16  tfidf   0.025       3   True   True       89120        0.529736
# 17  tfidf   0.025       3   True  False       89120        0.529707
# 8   tfidf   0.050       3   True   True       89176        0.530252
# 9   tfidf   0.050       3   True  False       89176        0.530222
# 0   tfidf   0.100       3   True   True       89202        0.530330
# 1   tfidf   0.100       3   True  False       89202        0.530296
# 30  tfidf   0.010       5  False   True       78756        0.525913
# 31  tfidf   0.010       5  False  False       78756        0.525853
# 4   tfidf   1.000       3   True   True       89225        0.529841
# 5   tfidf   1.000       3   True  False       89225        0.529823
# 7   tfidf   0.100       5  False  False       79004        0.527415
# 6   tfidf   0.100       5  False   True       79004        0.527437
# 22  tfidf   0.025       5  False   True       78921        0.526752
# 23  tfidf   0.025       5  False  False       78921        0.526712
# 15  tfidf   0.050       5  False  False       78980        0.527481
# 14  tfidf   0.050       5  False   True       78980        0.527454
# 10  tfidf   1.000       5  False   True       79026        0.527556
# 11  tfidf   1.000       5  False  False       79026        0.527523
# 28  tfidf   0.010       5   True   True       62719        0.507282
# 29  tfidf   0.010       5   True  False       62719        0.507278
# 21  tfidf   0.025       5   True  False       62881        0.508709
# 20  tfidf   0.025       5   True   True       62881        0.508691
# 12  tfidf   0.050       5   True   True       62937        0.509113
# 13  tfidf   0.050       5   True  False       62937        0.509095
# 4   tfidf   0.100       5   True   True       62963        0.509327
# 5   tfidf   0.100       5   True  False       62963        0.509204
# 8   tfidf   1.000       5   True   True       62986        0.509238
# 9   tfidf   1.000       5   True  False       62986        0.509193
#
#     train_macro_f1  test_micro_f1  test_macro_f1        of
# 2         0.653427       0.395418       0.395348  0.257979
# 3         0.653321       0.395341       0.395272  0.257950
# 0         0.618322       0.396573       0.396383  0.221768
# 1         0.618244       0.396517       0.396326  0.221746
# 26        0.551873       0.390984       0.390717  0.161017
# 27        0.551831       0.390939       0.390676  0.161017
# 19        0.552399       0.393916       0.393617  0.158605
# 18        0.552400       0.393938       0.393638  0.158585
# 10        0.552746       0.394485       0.394181  0.158393
# 11        0.552720       0.394490       0.394188  0.158361
# 2         0.552546       0.394927       0.394605  0.157763
# 3         0.552471       0.394988       0.394668  0.157626
# 6         0.552293       0.395440       0.395092  0.157011
# 7         0.552290       0.395451       0.395104  0.156997
# 25        0.528368       0.391287       0.390860  0.137358
# 24        0.528383       0.391331       0.390906  0.137329
# 16        0.529501       0.394275       0.393889  0.135461
# 17        0.529471       0.394397       0.394011  0.135310
# 8         0.530003       0.395159       0.394755  0.135094
# 9         0.529972       0.395170       0.394761  0.135052
# 0         0.530067       0.395612       0.395179  0.134718
# 1         0.530034       0.395634       0.395201  0.134663
# 30        0.525689       0.391840       0.391490  0.134073
# 31        0.525629       0.391840       0.391490  0.134014
# 4         0.529562       0.396528       0.396081  0.133312
# 5         0.529544       0.396562       0.396115  0.133261
# 7         0.527185       0.394899       0.394483  0.132516
# 6         0.527208       0.394977       0.394561  0.132461
# 22        0.526539       0.394341       0.393984  0.132411
# 23        0.526501       0.394303       0.393948  0.132409
# 15        0.527272       0.395253       0.394863  0.132229
# 14        0.527244       0.395253       0.394862  0.132201
# 10        0.527291       0.395783       0.395370  0.131773
# 11        0.527258       0.395794       0.395385  0.131729
# 28        0.506903       0.392541       0.391965  0.114741
# 29        0.506900       0.392541       0.391965  0.114737
# 21        0.508358       0.395247       0.394704  0.113462
# 20        0.508343       0.395236       0.394691  0.113455
# 12        0.508753       0.395949       0.395374  0.113164
# 13        0.508735       0.396004       0.395433  0.113091
# 4         0.508951       0.396782       0.396190  0.112544
# 5         0.508826       0.396749       0.396156  0.112454
# 8         0.508851       0.397014       0.396411  0.112224
# 9         0.508804       0.397042       0.396439  0.112151

# %%
full_results2['of'] = full_results2['train_micro_f1'] - full_results2['test_micro_f1']

# %%
# best is 1.0, 5, true, false

cv = CountVectorizer(max_df = 1.0, min_df = 5, lowercase = True)
X_train_counts = cv.fit_transform(X_train)
X_test_counts = cv.transform(X_test)

# record vocab size for tracking
vocab_size = X_train_counts.shape[1]

# tf-idf version
print("TF-IDF vectorizing at " + str(datetime.datetime.now()))
tv = TfidfTransformer()
X_train_tfidf = tv.fit_transform(X_train_counts)
X_test_tfidf = tv.transform(X_test_counts)

# fit an SVM on tf-idf version
print("Fitting TF-IDF count SVM at " + str(datetime.datetime.now()))
model = LinearSVC(dual = False, random_state = 771, max_iter = 5000)
model.fit(X_train_tfidf, y_train)

# evaluate 
print("Evaluating TF-IDF SVM at " + str(datetime.datetime.now()))
tf_y_train_pred = model.predict(X_train_tfidf)
tf_y_test_pred = model.predict(X_test_tfidf)

tf_train_f1_micro = f1_score(y_train, tf_y_train_pred, average = 'micro')
tf_train_f1_macro = f1_score(y_train, tf_y_train_pred, average = 'macro')

tf_test_f1_micro = f1_score(y_test, tf_y_test_pred, average = 'micro')
tf_test_f1_macro = f1_score(y_test, tf_y_test_pred, average = 'macro')
# Out:
# TF-IDF vectorizing at 2020-11-22 19:35:20.515322
# Fitting TF-IDF count SVM at 2020-11-22 19:35:22.018314
# Evaluating TF-IDF SVM at 2020-11-22 19:38:07.356068
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-3647b09be9dd> in <module>
#      30
#      31 with open('../models/best_svm.p', 'wb') as f:
# ---> 32     pickle.dump(model, f)
#      33
#      34 with open('../models/svm_vectorizer.p', 'wb') as f:
#
# NameError: name 'pickle' is not defined

# %%
# save artefacts to file for reuse
with open('../models/best_svm.p', 'wb') as f:
    pickle.dump(model, f)

with open('../models/svm_tfidf.p', 'wb') as f:
    pickle.dump(tv, f)

with open('../models/svm_cv.p', 'wb') as f:
    pickle.dump(cv, f)

# %% [markdown]
# ## Evaluate on BERT test set

# %%
bert_test = pd.read_csv("../data/final_eval_set.csv", index_col = 0)
int_cats = {"good": 0, "controversial": 1, "bad": 2}
X_bert_test = tv.transform(cv.transform(bert_test['text']))
y_pred_bert_test = model.predict(X_bert_test)
bert_test['svm_pred'] = pd.Series(y_pred_bert_test).map(int_cats)
bert_test['svm_match'] = bert_test['svm_pred'] == bert_test['true']

# %%
bert_test.groupby('svm_match').size().transform(lambda x: round(x/sum(x),3))
# Out:
# svm_match
# False    0.609
# True     0.391
# dtype: float64

# %%
bert_test.head()
# Out:
#    bert_pred  true                                               text  \
# 0          0     0  One nickname for the city of Columbus, Ohio. C...
# 1          1     1  -adjective ;; used to denote an ignorant or fo...
# 2          2     0                     someone that is really stupid.
# 3          2     2  Nasty pieces of poopoo that just will not come...
# 4          0     2  A hardedend clump of fecal matter attached to ...
#
#    bert_match  log_pred  log_match  svm_pred  svm_match
# 0        True         1      False         1      False
# 1        True         1       True         1       True
# 2       False         2      False         2      False
# 3        True         2       True         2       True
# 4       False         2       True         1      False

# %%
bert_test.to_csv("../data/final_eval_set.csv")

# %% [markdown]
# ## Example prediction

# %%
tf_y_test_pred
# Out:
# array(['bad', 'controversial', 'controversial', ..., 'controversial',
#        'good', 'bad'], dtype=object)

# %%
def pred_ex(text, count_vectorizer, tfidf_vectorizer, model):
    text = tfidf_vectorizer.transform(count_vectorizer.transform([text]))
    pred = model.predict(text)
    print(pred[0])

# %%
pred_ex("this could be a very good definition", cv, tv, svm_tf)
pred_ex("nonsense nonsense yada yada", cv, tv, svm_tf)
pred_ex("this is an example of a definition with interesting words and content like a car and a house", cv, tv, svm_tf)
pred_ex("merrily we roll along", cv, tv, svm_tf)
pred_ex("rudolph the red-nosed reindeer had a very shiny nose", cv, tv, svm_tf)
# Out:
# bad
# bad
# bad
# controversial
# bad

# %% [markdown]
# ## Write train and test to file

# %%
train_rejoin = pd.DataFrame()
train_rejoin['defn'] = X_train
train_rejoin['cat'] = y_train

# %%
test_rejoin = pd.DataFrame()
test_rejoin['defn'] = X_test
test_rejoin['cat'] = y_test

# %%
train_rejoin.groupby('cat').size().transform(lambda x: x/sum(x))
# Out:
# cat
# bad              0.333563
# controversial    0.344133
# good             0.322304
# dtype: float64

# %%
train_rejoin.to_csv("../data/svm_data/train.csv", index = False)
test_rejoin.to_csv("../data/svm_data/test.csv", index = False)
